# %% [markdown]
# # <div align='center'>Introduction to Python for data analysis: Data visualization libraries</div>
#
# Effective data analysis often relies on the ability to convey insights through visual representations. In this course, we'll delve into three of Python's most widely used data visualization libraries, [matplotlib](https://matplotlib.org/), [Plotly](https://plotly.com/python/) and [seaborn](https://seaborn.pydata.org/), showcasing their power through practical examples.
#
# # Contents
#
# 1. <a href="#matplotlib">The matplotlib library</a>
#     1. <a href="#matplotlib_hist">How to make a histogram?</a>
#     2. <a href="#matplotlib_bar">How to make a bar plot?</a>
#     3. <a href="#matplotlib_line">How to make a line plot?</a>
#     4. <a href="#matplotlib_scatter">How to make a scatter figure?</a>
#     5. <a href="#matplotlib_style">Style your figures</a>
#     6. <a href="#matplotlib_multiple_lines">How to show two or more line plot lines together?</a>
#     7. <a href="#matplotlib_stack">How to make a stack plot?</a>
#     8. <a href="#matplotlib_grouped_bar_chart">How to make a grouped bar chart?</a>
#     9. <a href="#matplotlib_savefig">How to save figures?</a>
# 2. <a href="#plotly">The Plotly library</a>
#     1. <a href="#plotly_hists">Histograms</a>
#     2. <a href='#plotly_bar_charts'>Bar charts</a>
#     3. <a href='#plotly_line_charts'>Line charts</a>
#     4. <a href='#plotly_scatter_plots'>Scatter plots</a>
#     5. <a href="#plotly_export">How to export figures?</a>
# 3. <a href="#seaborn">The seaborn library</a>
#     1. <a href='#plotly_hists'>Histograms and bar charts</a>
#     2. <a href='#plotly_line_plots'>Line plots</a>
#     3. <a href='#plotly_scatter_plots'>Scatter plots</a>
#     4. <a href='#plotly_savefig'>How to export figures?</a>

# %% [markdown]
# ## <div id='matplotlib'>1. The matplotlib library</div>
#
# Let's first import the matplotlib library:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# If the above didn't work, please run the following on a terminal/console:
# ```
# pip install matplotlib
# ```
# or
# ```
# pip3 install matplotlib
# ```

# %% [markdown]
# ### <div id='matplotlib_hist'>1.A. How to make a histogram?</div>
#
# *In a histogram, the axis representing the data is divided into a set of discrete bins and the count of observations in each bin is shown using the height of the corresponding bar.*
#
# A histogram can be produced using the ```hist()``` function. Let's see an example, let's generate numbers in the [0,10] range and make a histogram, if the number of generated numbers is sufficiently high, the distribution should be flat.

# %%
from random import randrange

# Geneate 100000 random numbers b/w 0 and 10
n_to_generate = 100000
numbers = [randrange(10) for _ in range(n_to_generate)]

# Plot the distribution of the generated numbers
plt.hist(numbers)
plt.show()

# %% [markdown]
# For more information and options see [matplotlib.pyplot.hist](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html).
#
# **Note:** A histogram shows values for numerical data, while a bar plot (see following section) shows values over categorical data.

# %% [markdown]
# ### <div id='matplotlib_bar'>1.B. How to make a bar plot?</div>
#
# A bar plot/chart can be produced using the ```bar(x, height)``` function. The ```x``` argument should be used to set the coordinates of the bars, while the ```height``` argument sets the height(s) of the bars.
#
# Let's see an example, I will create dictionary containing different categories each associated to a numerical value which will be the height of each category. For example, this dictionary could represent the number of sales for different categories of products. I will then sort the dictionary by values (not keys) and then make a bar chart.

# %%
data_dict = {
    'CategoryA': 121,
    'CategoryB': 154,
    'CategoryC': 118,
    'CategoryD': 183,
    'CategoryE': 89,
    'CategoryF': 117
}
sorted_data_dict = dict(sorted(data_dict.items(), key=lambda x:x[1], reverse=True))

# Plot the distribution of the generated numbers
plt.bar(sorted_data_dict.keys(), sorted_data_dict.values())
plt.show()

# %% [markdown]
# You can find more information and examples for bar charts in [matplotlib.pyplot.bar](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html).

# %% [markdown]
# ### <div id='matplotlib_line'>1.C. How to make a line plot?</div>
#
# Let's generate data that shows a perfect linear dependency and create a line plot using the ```plot()``` function:

# %%
# Let's generate (x,y) points
x = [0, 1, 2, 3, 4, 5, 6]
y = [item * 2 for item in x]

# Let's plot y vs x
plt.plot(x, y)
plt.show()

# %% [markdown]
# We could also show those points as markerts instead of showing them as a line. Here is how you do it:

# %%
# Let's plot y vs x
plt.plot(x, y, marker = 'o', linestyle = "None")
plt.show()

# %% [markdown]
# Learn about other marker options [here](https://matplotlib.org/stable/api/markers_api.html).
#
# Learn about other line style options [here](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html).
#
# For more information and options in the ```plot()``` functions see [matplotlib.pyplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html).

# %% [markdown]
# ### <div id='matplotlib_scatter'>1.D. How to make a scatter figure?</div>
#
# Let's generate some random data along two axes and make a scatter figure:

# %%
# Generate data
from random import gauss
npoints = 1000
x_scattered = [gauss(5, 1) for _ in range(npoints)]
y_scattered = [gauss(100, 10) for _ in range(npoints)]

# Make a scatter figure
plt.scatter(x_scattered, y_scattered)
plt.show()

# %% [markdown]
# For more information and options see [matplotlib.pyplot.scatter](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html).

# %% [markdown]
# ### <div id='matplotlib_style'>1.E. Style your figures</div>
#
# #### Axis labels
#
# For labeling the x-axis (y-axis), we use the ```xlabel()``` (```ylabel()```) function. Let's reproduce the histogram and add axis labels:

# %%
# Plot the distribution of the generated numbers
plt.hist(numbers)
plt.xlabel('Randomly-generated number')
plt.ylabel('Entries')
plt.show()

# %% [markdown]
# #### Legends
#
# Legends are short text descriptions of the curves/histograms/scatter plots shown. They are particular helpful when showing two or more line plots/histograms together, so the user can easily identify what is being shown.
#
# When creating a histogram, a line plot, a bar chart or a scatter figure, we can add a label (a string that identifies it) by setting the ```label``` argument. Then, we can show all legends by using the ```legend()``` function. The position where the legend is shown is chosen automatically but we can choose a position ourselves by setting the ```loc``` attribute (options: ```'upper left'```, ```'upper right'```, ```'upper center'```, ```'lower left'```, ```'lower right'```, ```'lower center'```, ```'center left'```, ```'center right'```, ```'center'```).
#
# Let's continue with our histogram produced before and add a legend to the lower left corner:

# %%
# Plot the distribution of the generated numbers
plt.hist(numbers, label='Uniform distribution')
plt.xlabel('Randomly-generated number')
plt.ylabel('Entries')
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# You can find more information about legends in [matplotlib.pyplot.legend](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html).

# %% [markdown]
# #### Axes ranges
#
# Let's come back to the scatter figure we produced before and image we wish to restrict the ranges of the axes. We can do that by using the ```xlim()``` and ```ylim()``` functions, respectively for the ```x``` and ```y``` axes. Let's reproduce the scatter figure but restricting the ```x``` axis to the ```[3, 7]``` range and the ```y``` axis to the ```[80, 120]``` range:

# %%
# Make a scatter figure with new axes
plt.scatter(x_scattered, y_scattered)
plt.xlim([3, 7])
plt.ylim([80, 120])
plt.show()

# %% [markdown]
# #### Colors
#
# In every figure, we can choose the color of the objects being shown. In order to choose the color, we just need to set the ```color``` argument. For example, let's redo the histogram and set its color to green (we can use ```'green'``` or just ```'g'```):

# %%
# Plot the distribution of the generated numbers
plt.hist(numbers, label='Uniform distribution', color='green')
plt.xlabel('Randomly-generated number')
plt.ylabel('Entries')
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# You can find the full list of supported colors [here](https://matplotlib.org/stable/gallery/color/named_colors.html).

# %% [markdown]
# #### Add text to figures
#
# Sometimes, we wish to add text to our figures. We can do that using the ```text(x, y, s)``` function, where ```x``` and ```y``` determines the position to place the text (coordinates in the x and y axes), and ```s``` is the text to display.
#
# For example, let's add some text to the histogram above:

# %%
# Plot the distribution of the generated numbers
plt.hist(numbers, label='Uniform distribution', color='green')
plt.xlabel('Randomly-generated number')
plt.ylabel('Entries')
plt.legend(loc='lower left')
plt.text(x=4, y=6000, s="I'm using matplotlib", color='white')
plt.show()

# %% [markdown]
# For more information, see [matplotlib.pyplot.text](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html).

# %% [markdown]
# ### <div id='matplotlib_multiple_lines'>1.F. How to show two or more line plots together?</div>
#
# Before calling ```plt.show()```, we can create as many plots we need. Although, remember to set different colors, linestyles and labels such that they can properly be distinguished. Here is an example:

# %%
# Let's generate two sets of (x,y) points
x = [0, 1, 2, 3, 4, 5, 6]
y_a = [item * 2 for item in x]
y_b = [-2 + item * 3 for item in x]

# Let's plot y vs x
plt.plot(x, y_a, color='b', linestyle='-', label='A')
plt.plot(x, y_b, color='g', linestyle='--', label='B')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### <div id='matplotlib_stack'>1.G. How to make a stack plot?</div>
#
# Stack plots in matplotlib are created with the ```stackplot(x, y)``` function, where ```x``` is an array of shape ```(N, )``` and ```y``` is an array of shape ```(M, N)```. Here is an example:

# %%
import numpy as np

# Create a dictionary to store the data
products = ['ProductA', 'ProductB', 'ProductC']
sales = {  # array of sales by product vs days
    1: [14, 24, 23],
    2: [12, 25, 21],
    3: [19, 18, 27],
    4: [17, 22, 20],
    5: [20, 19, 19],
    6: [15, 23, 22],
    7: [16, 24, 24],
}
days = list(sales.keys())

# Create a numpy array from the dict and transpose it
# This will give us an array of arrays.
# The inner array contains sales per day for a given product while the outer array separates by product
data = np.array(list(sales.values())).T

# Create stack plot and style it
plt.stackplot(days, data, labels=products)
plt.xlabel('Days')
plt.ylabel('Sales')
plt.ylim([0, 85])
plt.legend()

# Print the figure
plt.show()

# %% [markdown]
# For more information about stack plots, see [matplotlib.pyplot.stackplot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.stackplot.html).

# %% [markdown]
# ### <div id='matplotlib_grouped_bar_chart'>1.H. How to make a grouped bar chart?</div>
#
# Let's add further separation to the dictionary created before. We will separate the sales not only by category but also by countries, we will concentrate on only three categories (CategoryA, CategoryB and CategoryC) for simplicity.
#
# We will create a grouped bar chart. We will have the categories in the x-axis and on each category, we will show a bar for each country. Here is how I will do it:
#
# - First, I will create a numerical axis for the categories
# - Then, for each country I'll create a bar chart where each bar for each category has an offset that is different for each country
#
# Here is a full example:

# %%
# Prepare the data
categories = ['CategoryA', 'CategoryB', 'CategoryC']
data_dict = {
    'France': [80, 56, 43],
    'Spain': [20, 51, 54],
    'Switzerland': [21, 47, 22],
}

# Create numerical axis
x = np.arange(len(categories))

# Set the width of the bars
width = 0.25

# Create figure and axis
fig, ax = plt.subplots()

# Create bars
for i, (country, sales) in enumerate(data_dict.items()):
    offset = width * i  # offset in the x-axis (different for each bar)
    bar = ax.bar(x + offset, sales, width=width, label=country)
    ax.bar_label(bar)  # show numbers on top of bars

# Label the axes
ax.set_xlabel('Categories')
ax.set_ylabel('Sales')

# Show category names
ax.set_xticks(x + width, categories)

# Add legends
ax.legend(loc='upper right', ncols=3)

# Show figure
plt.show()

# %% [markdown]
# ### <div id='matplotlib_savefig'>1.I. How to save figures?</div>
#
# We can save figures using the ```savefig()``` function. For example, we could use the following: ```plt.savefig('myfigure.png')```. We can save figures in png, pdf, svg and other formats. For more information, see [matplotlib.pyplot.savefig](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html).

# %% [markdown]
# ## <div id='plotly'>2. The Plotly library</div>
#
# Plotly is a powerful library for creating interactive data visualizations. Plotly figures can be displayed in Jupyter notebooks, be saved to HTML files to be viewed in a web browser, or be part a Python-built web applications using Dash (e.g. a web-based dashboard). When figures are viewed in a web browser or a jupyter notebook, you can hover over data points, zoom in/out, and show/hide data by clicking on the legends.
#
# In this course, I will mostly introduce you to Plotly Express. [Plotly Express](https://plotly.com/python/plotly-express/) is the easy-to-use, high-level interface to Plotly, which operates on a variety of types of data and produces easy-to-style figures.
#
# Here are some of the types of data that you can use in all the functions that I will mention in the following sections:
#
# - Pandas DataFrame
# - Lists or NumPy arrays
# - Dictionary
# - Result of a SQL query
#
# In most of my examples, I will use a dictionary, but the same syntax works if a DataFrame is used instead.
#
# If you wish to learn about using Dash to build web applications using Plotly, [check this out](https://dash.plotly.com/).

# %% [markdown]
# Let's start and import the plotly library:

# %%
import plotly.express as px

# %% [markdown]
# If the above didn't work, please run the following on a terminal/console:
# ```
# pip install plotly
# ```
# or
# ```
# pip3 install plotly
# ```

# %% [markdown]
# In the following sections, I will explain how to make histograms, bar charts, line charts and scatter plots. Moreover, I will explain how to export figures to static image file formats (PNG, SVG, PDF, etc) or to HTML which can be opened in a browser and remain interactive.

# %% [markdown]
# ### <div id='plotly_hists'>2.A. Histograms</div>
#
# In Plotly, a histogram is an aggregated bar chart, with several possible aggregation functions (count, sum, average, etc) which can be used to visualize data on categorical and date axes as well as linear axes.
#
# Let's take a look at an example where we will look at (randomly-generated) data from a hotel booking website. Specifically, we will look at the number of users and the number of bookings by date.

# %%
import pandas as pd

# Helpful dict to convert day number from datatime to string
weekdays = {
    1: "Monday",
    2: "Tuesday",
    3: "Wednesday",
    4: "Thursday",
    5: "Friday",
    6: "Saturday",
    7: "Sunday"
}

# Generate data (nusers and nbookings per day)
from random import gauss
from datetime import datetime
ndays = 120  # number of days
dates = [np.datetime64('2023-03-01') + np.timedelta64(i, 'D') for i in range(ndays)]
days = [weekdays[i.astype(datetime).isoweekday()] for i in dates]
number_of_users = [int(gauss(1000, 50)) for _ in range(ndays)]
number_of_bookings = [int(gauss(0.2*i, 0.01*i)) for i in number_of_users]
data_users_dict = {
    'date': dates,  # date in ISO 8601 format
    'day': days,  # day of week (string)
    'number_of_users': number_of_users,
    'number_of_bookings': number_of_bookings
}

# Create and show histogram with Plotly
fig = px.histogram(data_users_dict, x="number_of_users")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="860117c4-aa31-455f-9b15-fa07698d4eb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("860117c4-aa31-455f-9b15-fa07698d4eb9")) {                    Plotly.newPlot(                        "860117c4-aa31-455f-9b15-fa07698d4eb9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"number_of_users=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,978,1011,949,1004,1022,1010,1074,929,963,1035,1031,961,981,1021,1042],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size": ...

# %% [markdown]
# **Note:**
# - I could have just used: ```px.histogram(x=number_of_users)```
# - We could create a DataFrame out of the dictionary
# - If we use a DataFrame in which there is only one column, then there is no need to set the ```x``` argument.

# %% [markdown]
# #### Choosing the number of bins
#
# By default, the number of bins is chosen so that is comparable to the typical content in a bin. This number can be customized by setting the ```nbins``` argument. Example:

# %%
fig = px.histogram(data_users_dict, x="number_of_users", nbins=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2a103d5e-4a84-4bfb-89a6-2731c7bbb0c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a103d5e-4a84-4bfb-89a6-2731c7bbb0c4")) {                    Plotly.newPlot(                        "2a103d5e-4a84-4bfb-89a6-2731c7bbb0c4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"number_of_users=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":10,"offsetgroup":"","orientation":"v","showlegend":false,"x":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,978,1011,949,1004,1022,1010,1074,929,963,1035,1031,961,981,1021,1042],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"over ...

# %% [markdown]
# #### Choosing the aggregation function
#
# Suppose we now want to see the average number of bookings vs the number of users (if everything works well, we should see a trend, the higher the number of users, then the higher the number of bookings). We can do this by setting the variable to use in the y axis with the ```y``` argument and we can choose the aggregation function with the ```histfunc``` argument. This is how it will look like:

# %%
fig = px.histogram(data_users_dict, x="number_of_users", y='number_of_bookings', histfunc='avg')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="41af5e7d-4b7c-456f-8873-a1a08de4d75e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41af5e7d-4b7c-456f-8873-a1a08de4d75e")) {                    Plotly.newPlot(                        "41af5e7d-4b7c-456f-8873-a1a08de4d75e",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"avg","hovertemplate":"number_of_users=%{x}\u003cbr\u003eavg of number_of_bookings=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,978,1011,949,1004,1022,1010,1074,929,963,1035,1031,961,981,1021,1042],"xaxis":"x","y":[193,217,191,199,171,214,207,185,196,198,202,171,199,208,203,178,199,184,187,227,202,207,188,182,205,212,204,204,185,202,209,196,214,229,222,185,197,184,210,210,188,212,210,207,187,203,184,198,170,200,185,178,210,208,206,212,208,225,206,175,194,228,195,225,201,191,191,203,199,194,185,180,189,184,202,212,202,202,189,208,198,201,163,232,210,181,183,211,222,210,187,194,168,178,203,178,185,220,177,201,185,194,208,216,197,195,201,168,197,200,205,232,200,189,201,225,187,169,205,220],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %% [markdown]
# **Note:**
# - When the ```y``` argument is set, ```'sum'``` is used as default for ```histfunc```.
# - I could have used ```fig = px.histogram(x=number_of_users, y=number_of_bookings, histfunc='avg')``` as well.

# %% [markdown]
# As mentioned before, we can also use a column with categorical data. As an example, let's plot the average number of users per day of the week:

# %%
fig = px.histogram(data_users_dict, x="day", y='number_of_users', histfunc='avg')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="85eb6a35-1254-4410-ab44-e94fb7a72c39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85eb6a35-1254-4410-ab44-e94fb7a72c39")) {                    Plotly.newPlot(                        "85eb6a35-1254-4410-ab44-e94fb7a72c39",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"avg","hovertemplate":"day=%{x}\u003cbr\u003eavg of number_of_users=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday"],"xaxis":"x","y":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,978,1011,949,1004,1022,1010,1074,929,963,1035,1031,961,981,1021,1042],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# As you can see, the first bin is ```Wednesday```. This is because the day in our dictionary is Wednesday. If we wish to force an specific order in the binning, we need to set the ```category_orders``` argument. For example:

# %%
fig = px.histogram(data_users_dict, x="day", y='number_of_users', histfunc='avg', category_orders=dict(day=list(weekdays.values())))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57d17ddc-07bd-470f-90ac-619e19e28827" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57d17ddc-07bd-470f-90ac-619e19e28827")) {                    Plotly.newPlot(                        "57d17ddc-07bd-470f-90ac-619e19e28827",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"avg","hovertemplate":"day=%{x}\u003cbr\u003eavg of number_of_users=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday"],"xaxis":"x","y":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,978,1011,949,1004,1022,1010,1074,929,963,1035,1031,961,981,1021,1042],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# Furthermore, we can also use dates in the x-axis:

# %%
fig = px.histogram(data_users_dict, x="date", y='number_of_users', histfunc='avg')
fig.update_layout(bargap=0.2)  # separate bars for better visualization
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a3a2085d-d208-46bc-add2-044dbbcbff5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3a2085d-d208-46bc-add2-044dbbcbff5a")) {                    Plotly.newPlot(                        "a3a2085d-d208-46bc-add2-044dbbcbff5a",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"avg","hovertemplate":"date=%{x}\u003cbr\u003eavg of number_of_users=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["2023-03-01T00:00:00","2023-03-02T00:00:00","2023-03-03T00:00:00","2023-03-04T00:00:00","2023-03-05T00:00:00","2023-03-06T00:00:00","2023-03-07T00:00:00","2023-03-08T00:00:00","2023-03-09T00:00:00","2023-03-10T00:00:00","2023-03-11T00:00:00","2023-03-12T00:00:00","2023-03-13T00:00:00","2023-03-14T00:00:00","2023-03-15T00:00:00","2023-03-16T00:00:00","2023-03-17T00:00:00","2023-03-18T00:00:00","2023-03-19T00:00:00","2023-03-20T00:00:00","2023-03-21T00:00:00","2023-03-22T00:00:00","2023-03-23T00:00:00","2023-03-24T00:00:00","2023-03-25T00:00:00","2023-03-26T00:00:00","2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-01T00:00:00","2023-04-02T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00"],"xaxis":"x","y":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,97 ...

# %% [markdown]
# #### Setting axes titles
#
# Let's reproduce one of the examples above and use the ```update_layout()``` function to set the x-axis (y-axis) title with its ```xaxis_title``` (```yaxis_title```) argument.

# %%
fig = px.histogram(data_users_dict, x="number_of_users", y='number_of_bookings', histfunc='avg')
fig.update_layout(
    xaxis_title="# users",
    yaxis_title="Average # bookings",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="96b0dc4e-c1d4-4fe5-a801-4cf93e2805c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96b0dc4e-c1d4-4fe5-a801-4cf93e2805c5")) {                    Plotly.newPlot(                        "96b0dc4e-c1d4-4fe5-a801-4cf93e2805c5",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"avg","hovertemplate":"number_of_users=%{x}\u003cbr\u003eavg of number_of_bookings=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,978,1011,949,1004,1022,1010,1074,929,963,1035,1031,961,981,1021,1042],"xaxis":"x","y":[193,217,191,199,171,214,207,185,196,198,202,171,199,208,203,178,199,184,187,227,202,207,188,182,205,212,204,204,185,202,209,196,214,229,222,185,197,184,210,210,188,212,210,207,187,203,184,198,170,200,185,178,210,208,206,212,208,225,206,175,194,228,195,225,201,191,191,203,199,194,185,180,189,184,202,212,202,202,189,208,198,201,163,232,210,181,183,211,222,210,187,194,168,178,203,178,185,220,177,201,185,194,208,216,197,195,201,168,197,200,205,232,200,189,201,225,187,169,205,220],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %% [markdown]
# **Note:**
# - The same can be achieved using ```update_xaxes(title_text='# users')``` and ```update_yaxes(title_text='Average # bookings')```.
# - Alternatively, we can set axes titles with the ```labels``` argument. In this case, we should provide a ```dict``` where the key is the key from our dictionary for which we wish to change the title and its value is the name to be displayed in the corresponding axis.

# %% [markdown]
# #### Sorting bins based on content
#
# Let's come back to the example where we plotted the average number of users for each day and order the bins based on the y-axis values, from largest to lowest. This is how it can be done:

# %%
fig = px.histogram(data_users_dict, x="day", y='number_of_users', histfunc='avg').update_xaxes(categoryorder='total descending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8ce43b58-891d-44f4-b2cb-c682aa6b96c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ce43b58-891d-44f4-b2cb-c682aa6b96c3")) {                    Plotly.newPlot(                        "8ce43b58-891d-44f4-b2cb-c682aa6b96c3",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"avg","hovertemplate":"day=%{x}\u003cbr\u003eavg of number_of_users=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday","Monday","Tuesday","Wednesday"],"xaxis":"x","y":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,978,1011,949,1004,1022,1010,1074,929,963,1035,1031,961,981,1021,1042],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# #### Histograms with go.Histogram
#
# Sometimes, Plotly Express fall short and we need to use the more generic ```go.Histogram``` class from ```plotly.graph_objects```. Let's take a look at a couple of things that can be done with ```go.Histogram```.
#
# Let's fist import ```plotly.graph_objects```:

# %%
import plotly.graph_objects as go

# %% [markdown]
# <u>Plotting several histograms together:</u>

# %% [markdown]
# In this example, I will first generate data from two different Gaussian distributions. Then, I will create a ```go.Figure()``` object and add each histogram using the ```add_trace()``` function. I will set the ```name``` argument to have a meaningful legend and the same number of bins for eacy comparison through the ```nbinsx``` agument. I will also use the ```update_layout()``` function with ```barmode='overlay'``` to have overlayed histograms and I will set ```opacity``` to ```0.5``` so we can properly see both histograms. I'm also going to set the color for each histogram by setting the ```marker``` argument.

# %%
# Generate data
xA = [gauss(500, 5) for _ in range(1000)]
xB = [gauss(500, 3) for _ in range(1000)]

# Create go.Figure and add histograms
fig = go.Figure()
fig.add_trace(go.Histogram(x=xA, name='A', nbinsx=20, marker=go.histogram.Marker(color='black')))
fig.add_trace(go.Histogram(x=xB, name='B', nbinsx=20, marker=go.histogram.Marker(color='red')))

#marker=go.histogram.Marker(color="orange") # Change the color

# Overlay both histograms
fig.update_layout(barmode='overlay')

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca3c16a7-4dc7-44a4-b5de-bd68228e7997" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca3c16a7-4dc7-44a4-b5de-bd68228e7997")) {                    Plotly.newPlot(                        "ca3c16a7-4dc7-44a4-b5de-bd68228e7997",                        [{"marker":{"color":"black"},"name":"A","nbinsx":20,"x":[497.4977489186287,498.3463795171084,499.2328798895563,503.22797531098905,502.6075973488399,491.18366336221055,494.4186501587399,495.70337626188785,497.37613170137075,500.780204100978,495.4469937183826,498.768621486877,496.855554734341,498.4887538129937,505.7142549298518,495.9466942476423,496.3900803904745,502.0215180071446,508.243121061867,493.2295085319006,505.3437636712362,500.649634344945,499.1269301966749,496.37435720436406,499.82013067795907,502.98723313196103,502.21848133479875,500.05176979846345,498.2936509775963,494.2097592057966,490.61697624356196,504.8473431238264,494.1031787415133,510.207047407843,500.26730192021336,501.1014062674028,502.47797573345093,499.91600878863284,503.12363634385105,499.62684906275115,495.96135373566955,493.5750029085596,495.88918904445524,496.1703201151068,501.23545768699216,508.0301260112376,497.42297338829076,487.24512922323913,497.09551619898014,499.07130307907664,496.0214907013957,497.23795104060383,504.4308718816382,497.6844243735952,495.959766330847,493.92455116919024,502.48546327743855,505.0087014202862,498.35266382507115,502.3228217813821,509.7437161487019,500.95601389055884,504.7434270685201,502.26992460533137,492.1024337646442,499.4012823323011,496.5556395437227,496.17774486652814,502.0777004136935,505.31141244462884,495.01366807105444,498.7380537647126,493.5509682703743,500.6290938990388,503.24841121616265,506.1096946038067,495.8627593348471,499.729922215529,503.7897876325015,505.2561800705341,504.7026178274662,496.83671052540467,501.310981626303,501.03670823949545,495.07604240001075,509.6404701162466,499.52142303119183,506.0934066499274,489.3376605707236,499.2213443878169,506.2716227280271,508.3535844426969,502.4801042231208,501.27272121625646,499.4812533311114,504.780999416856,504.72416934480077,498.38358981083735,497.17045795028076,496.6692910784827,497.36542876392036,499.968548670624,501.66996816364474,488.91993681891404,496.68557527773953,502.1482353064195,502.5791007587499,503.8740289297294,511.2579156207446,506.4564409560527,495.87587181474214,490.69811879321463,494.4412668449379,505.58987146862063,499.2107814089757,502.6228551555962,495.3785510728454,500.7231933450297,496.2922500397805,495.6304480438558,499.5954300462866,494.42828845687603,498.1488798228815,511.15628414975066,495.50103406157893,501.9678277257055,496.1984409746938,495.51540605743514,497.81046626779806,496.3390045226836,502.12823024626886,497.47896474429314,497.27865315076315,498.8922090225689,502.34992312100627,494.7321658134451,497.2983143310398,502.5836623664348,511.6972702164203,500.7766380320208,499.2260121139946,495.44406797502165,507.4184086848961,507.15550265990026,504.49611908552686,503.8293618549594,505.426927074323,503.8872845079269,494.84984309968024,497.1395943201137,493.623016603525,500.4117405029541,495.0243138895469,496.29304877365036,501.61362788115525,497.61399347157624,494.6263454356228,490.84706489789227,499.8123190677966,499.99079764801115,510.7402065465751,506.53673822955795,510.0180640791365,501.16437642610197,497.83926667544813,504.33436813103776,500.76106405679843,508.35888116490713,503.36812113055197,497.06296015436544,501.39548966772253,499.97313089672593,505.96223433164784,497.81726320178603,497.8159705214757,499.7273455475487,505.8383201481004,506.70478941201503,491.46429258234264,496.32703909836874,505.4358351660429,503.6937009733575,506.81144885065044,498.90219283671433 ...

# %% [markdown]
# The full name of CSS named colors can be found in [plotly.graph_objects.histogram.marker](https://plotly.com/python-api-reference/generated/plotly.graph_objects.histogram.marker.html).

# %% [markdown]
# <u>Stacked Histograms</u>
#
# If we wish to stack both histograms instead of overlay them, we just need to set ```barmode``` to ```'stack'```. Let's reproduce the example above with stacked histograms:

# %%
# Create go.Figure and add histograms
fig = go.Figure()
fig.add_trace(go.Histogram(x=xA, name='A', nbinsx=20))
fig.add_trace(go.Histogram(x=xB, name='B', nbinsx=20))

# Stack both histograms
fig.update_layout(barmode='stack')

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ffc848e3-c569-4be0-9847-8fcc07c01a82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffc848e3-c569-4be0-9847-8fcc07c01a82")) {                    Plotly.newPlot(                        "ffc848e3-c569-4be0-9847-8fcc07c01a82",                        [{"name":"A","nbinsx":20,"x":[497.4977489186287,498.3463795171084,499.2328798895563,503.22797531098905,502.6075973488399,491.18366336221055,494.4186501587399,495.70337626188785,497.37613170137075,500.780204100978,495.4469937183826,498.768621486877,496.855554734341,498.4887538129937,505.7142549298518,495.9466942476423,496.3900803904745,502.0215180071446,508.243121061867,493.2295085319006,505.3437636712362,500.649634344945,499.1269301966749,496.37435720436406,499.82013067795907,502.98723313196103,502.21848133479875,500.05176979846345,498.2936509775963,494.2097592057966,490.61697624356196,504.8473431238264,494.1031787415133,510.207047407843,500.26730192021336,501.1014062674028,502.47797573345093,499.91600878863284,503.12363634385105,499.62684906275115,495.96135373566955,493.5750029085596,495.88918904445524,496.1703201151068,501.23545768699216,508.0301260112376,497.42297338829076,487.24512922323913,497.09551619898014,499.07130307907664,496.0214907013957,497.23795104060383,504.4308718816382,497.6844243735952,495.959766330847,493.92455116919024,502.48546327743855,505.0087014202862,498.35266382507115,502.3228217813821,509.7437161487019,500.95601389055884,504.7434270685201,502.26992460533137,492.1024337646442,499.4012823323011,496.5556395437227,496.17774486652814,502.0777004136935,505.31141244462884,495.01366807105444,498.7380537647126,493.5509682703743,500.6290938990388,503.24841121616265,506.1096946038067,495.8627593348471,499.729922215529,503.7897876325015,505.2561800705341,504.7026178274662,496.83671052540467,501.310981626303,501.03670823949545,495.07604240001075,509.6404701162466,499.52142303119183,506.0934066499274,489.3376605707236,499.2213443878169,506.2716227280271,508.3535844426969,502.4801042231208,501.27272121625646,499.4812533311114,504.780999416856,504.72416934480077,498.38358981083735,497.17045795028076,496.6692910784827,497.36542876392036,499.968548670624,501.66996816364474,488.91993681891404,496.68557527773953,502.1482353064195,502.5791007587499,503.8740289297294,511.2579156207446,506.4564409560527,495.87587181474214,490.69811879321463,494.4412668449379,505.58987146862063,499.2107814089757,502.6228551555962,495.3785510728454,500.7231933450297,496.2922500397805,495.6304480438558,499.5954300462866,494.42828845687603,498.1488798228815,511.15628414975066,495.50103406157893,501.9678277257055,496.1984409746938,495.51540605743514,497.81046626779806,496.3390045226836,502.12823024626886,497.47896474429314,497.27865315076315,498.8922090225689,502.34992312100627,494.7321658134451,497.2983143310398,502.5836623664348,511.6972702164203,500.7766380320208,499.2260121139946,495.44406797502165,507.4184086848961,507.15550265990026,504.49611908552686,503.8293618549594,505.426927074323,503.8872845079269,494.84984309968024,497.1395943201137,493.623016603525,500.4117405029541,495.0243138895469,496.29304877365036,501.61362788115525,497.61399347157624,494.6263454356228,490.84706489789227,499.8123190677966,499.99079764801115,510.7402065465751,506.53673822955795,510.0180640791365,501.16437642610197,497.83926667544813,504.33436813103776,500.76106405679843,508.35888116490713,503.36812113055197,497.06296015436544,501.39548966772253,499.97313089672593,505.96223433164784,497.81726320178603,497.8159705214757,499.7273455475487,505.8383201481004,506.70478941201503,491.46429258234264,496.32703909836874,505.4358351660429,503.6937009733575,506.81144885065044,498.90219283671433,498.8114091015479,495.8172 ...

# %% [markdown]
# You can find more information and tips for histograms in [plotly.com/python/histograms/](https://plotly.com/python/histograms/).

# %% [markdown]
# ### <div id='plotly_bar_charts'>2.B. Bar charts</div>
#
# Suppose we have a DataFrame, with ```px.bar```, each row of the DataFrame is represented as a rectangular mark (bar). If you wish to aggregate multiple data points into the same rectangular mark, you need a histogram (see <a href="#plotly_hists">2.A.a.</a>).
#
# Let's look at an example:

# %%
sales_dict = {
    'year': [2001, 2002, 2003, 2004, 2005, 2006],
    'sales': [1210000, 1540000, 1180000, 1830000, 890000, 1170000]
}

fig = px.bar(sales_dict, x='year', y='sales')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c6aa294d-8a9a-4403-bc5f-f8f2954b3a9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6aa294d-8a9a-4403-bc5f-f8f2954b3a9a")) {                    Plotly.newPlot(                        "c6aa294d-8a9a-4403-bc5f-f8f2954b3a9a",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[1210000,1540000,1180000,1830000,890000,1170000],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{ ...

# %% [markdown]
# #### Stacked bar charts
#
# <u>Bar charts with Long Format Data</u>
#
# In this type of bar charts, there will be a bar in the x-axis for each row of a column provided with the ```x``` argument. Each of those bars are further divided by the values present in another column (provided by the ```color``` argument).
#
# Let's look at a similar data to the one we used before but let's add another separation. The sales for every year are now further separated into countries. This is how we would display the data in a bar chart with long format data:

# %%
sales_dict = {
    'year': [year for year in [2001, 2002, 2003, 2004, 2005, 2006] for _ in range(3)],
    'country': ['Spain', 'France', 'Italy'] * 6,
    'sales': [gauss(10000000, 1000000) for _ in range(18)]
}

fig = px.bar(sales_dict, x="year", y="sales", color="country")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a9156852-82ee-4f22-9273-ffc6a8679515" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9156852-82ee-4f22-9273-ffc6a8679515")) {                    Plotly.newPlot(                        "a9156852-82ee-4f22-9273-ffc6a8679515",                        [{"alignmentgroup":"True","hovertemplate":"country=Spain\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spain","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Spain","offsetgroup":"Spain","orientation":"v","showlegend":true,"textposition":"auto","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10693860.536727473,9243045.695889438,10977472.367172088,10170724.28187688,11911253.481055208,9308362.39897796],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=France\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9390114.230513303,9610857.202434223,10159066.368806742,8559660.91852194,9645098.224757692,8998181.79501018],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=Italy\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9931814.847123846,8574893.45611801,9232395.218290891,10121499.11018939,9617501.845461057,7038906.438619876],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd37 ...

# %% [markdown]
# <u>Bar charts with Wide Format Data</u>
#
# This type of bar charts, there will be a bar in the x-axis for each row of a column provided with the ```x``` argument. Each of those bars are further divided by the list of columns provided in the ```y``` argument. For example, we can use this type of chart to display the revenue and profit for each year. Let's see how this would look like:

# %%
years = [2001, 2002, 2003, 2004, 2005, 2006]
revenue_per_year = [gauss(10000000, 1500000) for _ in years]
finances_dict = {
    'year': years,
    'revenue': revenue_per_year,
    'profit': [gauss(0.05, 0.01) * revenue for revenue in revenue_per_year]
}

fig = px.bar(finances_dict, x="year", y=["revenue", "profit"])
fig.update_yaxes(title_text='Total revenue and profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3c63452e-d0d7-4f00-9f8f-82852e0e1564" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c63452e-d0d7-4f00-9f8f-82852e0e1564")) {                    Plotly.newPlot(                        "3c63452e-d0d7-4f00-9f8f-82852e0e1564",                        [{"alignmentgroup":"True","hovertemplate":"variable=revenue\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"revenue","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"revenue","offsetgroup":"revenue","orientation":"v","showlegend":true,"textposition":"auto","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10733435.215054393,11138810.545562202,10347150.570367873,10984273.796729103,8974019.234585406,8609174.770097068],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=profit\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"profit","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"profit","offsetgroup":"profit","orientation":"v","showlegend":true,"textposition":"auto","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[488059.68353104586,512225.07365224056,533739.6148178043,527203.5434324489,441348.2545444334,429135.9521496299],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888, ...

# %% [markdown]
# #### Grouped bar charts
#
# By default, bar charts are stacked. This behaviour can be changed to grouped by setting the ```barmode``` argument to ```group```. Let's repeat the example above but let's show the data in a grouped bar chart:

# %%
fig = px.bar(finances_dict, x="year", y=["revenue", "profit"], barmode='group')
fig.update_yaxes(title_text='Total revenue and profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="80fb7496-ab35-48f1-82db-aa4881bb9518" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80fb7496-ab35-48f1-82db-aa4881bb9518")) {                    Plotly.newPlot(                        "80fb7496-ab35-48f1-82db-aa4881bb9518",                        [{"alignmentgroup":"True","hovertemplate":"variable=revenue\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"revenue","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"revenue","offsetgroup":"revenue","orientation":"v","showlegend":true,"textposition":"auto","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10733435.215054393,11138810.545562202,10347150.570367873,10984273.796729103,8974019.234585406,8609174.770097068],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=profit\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"profit","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"profit","offsetgroup":"profit","orientation":"v","showlegend":true,"textposition":"auto","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[488059.68353104586,512225.07365224056,533739.6148178043,527203.5434324489,441348.2545444334,429135.9521496299],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888, ...

# %% [markdown]
# #### How to show values on the bars?
#
# You can show the values on the bars by setting the ```text_auto``` argument to ```True```. Alternatively, you can set it to a d3-format formatting string to control the output format. For example, a string like ```'.2f'``` will show only two decimal numbers. Let's show again a stack bar chart for our previous financial data and show values on our bars:

# %%
fig = px.bar(finances_dict, x="year", y=["revenue", "profit"], text_auto=".3s")
fig.update_yaxes(title_text='Total revenue and profit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a6432ac2-02c5-40b6-9814-92234da16a98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6432ac2-02c5-40b6-9814-92234da16a98")) {                    Plotly.newPlot(                        "a6432ac2-02c5-40b6-9814-92234da16a98",                        [{"alignmentgroup":"True","hovertemplate":"variable=revenue\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"revenue","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"revenue","offsetgroup":"revenue","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.3s}","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10733435.215054393,11138810.545562202,10347150.570367873,10984273.796729103,8974019.234585406,8609174.770097068],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=profit\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"profit","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"profit","offsetgroup":"profit","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.3s}","x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[488059.68353104586,512225.07365224056,533739.6148178043,527203.5434324489,441348.2545444334,429135.9521496299],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"] ...

# %% [markdown]
# In this case, I used ```'.3s'``` to show only 3 significant digits. To learn more about d3-format, see [this](https://github.com/d3/d3-format/tree/v1.4.5).

# %% [markdown]
# If you can't find how to do something within Plotly Express, you might need to use the ```go.Bar``` class from ```plotly.graph_objects```.
#
# For more information about bar charts in Plotly Express or using ```go.Bar```, see [plotly.com/python/bar-charts/](https://plotly.com/python/bar-charts/).

# %% [markdown]
# ### <div id='plotly_line_charts'>2.C. Line charts</div>
#
# In order to make a line chart in Plotly Express, we need to use the ```line(data, x, y)``` function. Let's reuse our previous ```sales_dict``` dictionay and plot total sales vs year.

# %%
# Let's get total sales for each year
df = pd.DataFrame(sales_dict)
data = df.groupby('year')['sales'].sum().to_frame()

# Create a line chart
fig = px.line(data)
fig.update_yaxes(title_text='Sales')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="96823116-0fb8-4f4d-af21-0f9ffc5302e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96823116-0fb8-4f4d-af21-0f9ffc5302e3")) {                    Plotly.newPlot(                        "96823116-0fb8-4f4d-af21-0f9ffc5302e3",                        [{"hovertemplate":"variable=sales\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"sales","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"sales","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[30015789.614364624,27428796.354441673,30368933.954269722,28851884.31058821,31173853.551273957,25345450.632608015],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity": ...

# %% [markdown]
# #### Draw multiple lines
#
# Let's now show sales from each country for every year. Here is how we can do it:

# %%
fig = px.line(sales_dict, x='year', y='sales', color='country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="591120e6-6049-4f0f-8b32-df6dfe6855e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("591120e6-6049-4f0f-8b32-df6dfe6855e7")) {                    Plotly.newPlot(                        "591120e6-6049-4f0f-8b32-df6dfe6855e7",                        [{"hovertemplate":"country=Spain\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spain","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Spain","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10693860.536727473,9243045.695889438,10977472.367172088,10170724.28187688,11911253.481055208,9308362.39897796],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=France\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9390114.230513303,9610857.202434223,10159066.368806742,8559660.91852194,9645098.224757692,8998181.79501018],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Italy\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Italy","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9931814.847123846,8574893.45611801,9232395.218290891,10121499.11018939,9617501.845461057,7038906.438619876],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...

# %% [markdown]
# What about if we want different line styles for every country? We just need to set the ```line_dash``` argument. Example:

# %%
fig = px.line(sales_dict, x='year', y='sales', color='country', line_dash='country')
fig.update_traces(marker=dict(size=12))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="01741cba-1ba8-46e4-a6db-e52fe009c181" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01741cba-1ba8-46e4-a6db-e52fe009c181")) {                    Plotly.newPlot(                        "01741cba-1ba8-46e4-a6db-e52fe009c181",                        [{"hovertemplate":"country=Spain\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spain","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","size":12},"mode":"lines","name":"Spain","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10693860.536727473,9243045.695889438,10977472.367172088,10170724.28187688,11911253.481055208,9308362.39897796],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=France\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#EF553B","dash":"dot"},"marker":{"symbol":"circle","size":12},"mode":"lines","name":"France","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9390114.230513303,9610857.202434223,10159066.368806742,8559660.91852194,9645098.224757692,8998181.79501018],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Italy\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#00cc96","dash":"dash"},"marker":{"symbol":"circle","size":12},"mode":"lines","name":"Italy","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9931814.847123846,8574893.45611801,9232395.218290891,10121499.11018939,9617501.845461057,7038906.438619876],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953 ...

# %% [markdown]
# #### Line charts with markers
#
# If we wish to show markers, we just need to set the ```markers``` argument to ```True```. Let's see how it looks like for our example before:

# %%
fig = px.line(sales_dict, x='year', y='sales', color='country', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a9270542-70e9-43b1-8b62-e2944a96ae1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9270542-70e9-43b1-8b62-e2944a96ae1a")) {                    Plotly.newPlot(                        "a9270542-70e9-43b1-8b62-e2944a96ae1a",                        [{"hovertemplate":"country=Spain\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spain","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Spain","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10693860.536727473,9243045.695889438,10977472.367172088,10170724.28187688,11911253.481055208,9308362.39897796],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=France\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"France","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9390114.230513303,9610857.202434223,10159066.368806742,8559660.91852194,9645098.224757692,8998181.79501018],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Italy\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Italy","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9931814.847123846,8574893.45611801,9232395.218290891,10121499.11018939,9617501.845461057,7038906.438619876],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"], ...

# %% [markdown]
# We can also choose to use different markers for every curve, we can do that by setting the ```symbol``` argument. For example:

# %%
fig = px.line(sales_dict, x='year', y='sales', color='country', markers=True, symbol='country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="06f76b86-0cd7-4624-a017-491cbdf6bc0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06f76b86-0cd7-4624-a017-491cbdf6bc0f")) {                    Plotly.newPlot(                        "06f76b86-0cd7-4624-a017-491cbdf6bc0f",                        [{"hovertemplate":"country=Spain\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spain","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Spain","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10693860.536727473,9243045.695889438,10977472.367172088,10170724.28187688,11911253.481055208,9308362.39897796],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=France\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"diamond"},"mode":"lines+markers","name":"France","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9390114.230513303,9610857.202434223,10159066.368806742,8559660.91852194,9645098.224757692,8998181.79501018],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Italy\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"square"},"mode":"lines+markers","name":"Italy","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9931814.847123846,8574893.45611801,9232395.218290891,10121499.11018939,9617501.845461057,7038906.438619876],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"] ...

# %% [markdown]
# Let's now change the size of the markers:

# %%
fig = px.line(sales_dict, x='year', y='sales', color='country', markers=True, symbol='country')
fig.update_traces(marker=dict(size=12))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a49b3d63-a9c9-4f86-ada8-cfaaa0004996" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a49b3d63-a9c9-4f86-ada8-cfaaa0004996")) {                    Plotly.newPlot(                        "a49b3d63-a9c9-4f86-ada8-cfaaa0004996",                        [{"hovertemplate":"country=Spain\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spain","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","size":12},"mode":"lines+markers","name":"Spain","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[10693860.536727473,9243045.695889438,10977472.367172088,10170724.28187688,11911253.481055208,9308362.39897796],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=France\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"diamond","size":12},"mode":"lines+markers","name":"France","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9390114.230513303,9610857.202434223,10159066.368806742,8559660.91852194,9645098.224757692,8998181.79501018],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Italy\u003cbr\u003eyear=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"square","size":12},"mode":"lines+markers","name":"Italy","orientation":"v","showlegend":true,"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[9931814.847123846,8574893.45611801,9232395.218290891,10121499.11018939,9617501.845461057,7038906.438619876],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %% [markdown]
# #### Time-series charts
#
# Line plots using dates in the x-axis are often called time-series charts. Let's reuse our ```data_users_dict``` and plot the number of users vs date.

# %%
fig = px.line(data_users_dict, x='date', y="number_of_users")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b372865e-6de0-4806-a361-9c555c1b628c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b372865e-6de0-4806-a361-9c555c1b628c")) {                    Plotly.newPlot(                        "b372865e-6de0-4806-a361-9c555c1b628c",                        [{"hovertemplate":"date=%{x}\u003cbr\u003enumber_of_users=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2023-03-01T00:00:00","2023-03-02T00:00:00","2023-03-03T00:00:00","2023-03-04T00:00:00","2023-03-05T00:00:00","2023-03-06T00:00:00","2023-03-07T00:00:00","2023-03-08T00:00:00","2023-03-09T00:00:00","2023-03-10T00:00:00","2023-03-11T00:00:00","2023-03-12T00:00:00","2023-03-13T00:00:00","2023-03-14T00:00:00","2023-03-15T00:00:00","2023-03-16T00:00:00","2023-03-17T00:00:00","2023-03-18T00:00:00","2023-03-19T00:00:00","2023-03-20T00:00:00","2023-03-21T00:00:00","2023-03-22T00:00:00","2023-03-23T00:00:00","2023-03-24T00:00:00","2023-03-25T00:00:00","2023-03-26T00:00:00","2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-01T00:00:00","2023-04-02T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00"],"xaxis":"x","y":[1007,1063,936,1009,878,975,1072,973,987,991,1007,967,973,1043,1054,948,1035,976,1014,1084,951,1056,933,974,984,1045,1072,1036,978,999,1057,972,1035,1081,1025,1000,1038,946,1041,1072,1013,1005,1046,1017,963,989,970,1028,930,992,963,918,1090,1002,1026,1058,1065,1040,1019,985,984,1120,974,1104,1037,893,1006,1069,945,903,937,965,970,952,958,1041,990,990,971,1031,996,1056,905,1056,1057,937,1011,1026,1066,1016,961,1013,935,976,965,960,949,1049,941,1057,968,986,997,1067,919,978,1011,949,1004,1022,1010,1074,929,963,1035,10 ...

# %% [markdown]
# For more information about line charts, see [plotly.com/python/line-charts/](https://plotly.com/python/line-charts/).
#
# For more information and tips about time-series charts, see [plotly.com/python/time-series/](https://plotly.com/python/time-series/).

# %% [markdown]
# ### <div id='plotly_scatter_plots'>2.D. Scatter plots</div>
#
# Similarly to matplotlib, in plotly we just need to use the ```scatter(x, y)``` function to create a scatter figure.
#
# Let's reproduce the scatter plot we produced with matplotlib now with plotly:

# %%
fig = px.scatter(x=x_scattered, y=y_scattered)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="00709481-e371-45e6-8971-47ffec4b9969" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00709481-e371-45e6-8971-47ffec4b9969")) {                    Plotly.newPlot(                        "00709481-e371-45e6-8971-47ffec4b9969",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2.898036532143647,5.90044986452908,5.5623240183276765,5.701209266985526,5.678879284864808,6.280676533335491,3.9025642300713583,4.268330423827531,5.530488289852828,5.291740962976721,4.821897669414998,4.316676433278215,5.312871443659052,3.9976122459590653,5.730903176445895,4.254323174253994,6.025889219279248,5.946010726008841,3.874031469526506,6.013183225596819,4.4345311081593755,4.0382902198105946,5.594863287450458,7.188718122337145,5.772127364190823,5.0969199733136215,3.8106150187677184,5.982480970753998,5.250114283944902,5.74858749934428,6.074069164744669,4.5797176747773705,4.989572834206296,6.475708025956496,4.916995983313119,6.043335309369281,4.644511577453517,5.043211176476393,5.694740612001736,2.788228475541495,5.953223747484047,6.55014718414995,5.914155375397003,6.274755201445098,5.43801521598315,6.320944515345922,3.8882653077065257,5.524703843172612,4.2920303352774045,4.698658175504582,2.5573449018415375,6.437167361013554,5.165113281636775,5.880913401020949,4.917844867333112,3.124043004601992,4.006383235931417,5.704597542013722,6.0191593391462845,4.949154129144157,5.237620212664748,5.521779603844581,6.303729180370815,3.8589033569535456,4.352066140824581,5.2940969061409096,5.065926941361755,5.011976882163809,5.094350367941076,5.274993019880901,5.42698675480001,5.441810676735876,4.641201643231996,4.076249157881799,4.748347103631655,5.262040478881832,4.555225662778567,6.222754591672746,1.9882408347044271,6.684836485686004,4.672650474271763,4.980692606493008,5.761068261979945,6.028115807070257,5.003688225899082,5.839530855880274,3.59498835691883,4.506010814908421,4.701053240889091,3.9377955242609977,7.315012716217393,5.026946027579558,4.951453776945355,5.2493537429608566,5.758870560895738,6.17628785334505,3.7113165780923962,4.316101388011696,4.991047002853104,6.67654878656127,5.030113133436255,3.790801556917241,3.083526447474627,5.129585637697836,5.084452622441423,4.398376528117595,4.364521787820508,4.428650648686479,5.355078568774051,5.974504334725407,3.8425151465293674,4.650483762972855,5.290234839272775,6.56132882650942,5.918670972621164,7.07992572958052,5.041092305315609,5.236090040289437,5.935860126505528,3.5869694323734382,4.7162110640503645,5.031218651884923,5.75354881725363,5.134459530110145,4.862359920668873,6.140426544747796,5.378884567943976,4.651069235040849,5.003004518085179,4.447212229873264,5.148890043361116,3.680514539131054,4.5702957643086775,4.968136897564111,3.8741725470517654,7.841529516451467,4.647488248287064,5.076153767587452,4.37980866208016,5.622981614689957,4.004654441115914,5.691479701330624,6.861849421275544,3.820936661829238,4.500438842669537,3.270572967443192,7.189775600709995,4.672215860916303,5.374538237533957,4.938309952963145,5.422785718117081,3.9418626398104895,2.327448430409158,3.225839055505766,5.592761819241027,4.899886006506797,3.782258049412139,4.0466108332870965,2.704201141691198,4.078895508562847,6.510636608947452,4.386048587767602,5.734106390805213,6.435160907647525,4.730338634193427,6.288041866125402,6.366807531114563,5.499723726602811,3.130455528007835,4.885945264489023,5.493057462793851,3.9045365902168703,5.474243012879301,3.6705146681582645,3.6683733870793396,4.954513591774219,5.2454008893897885,6.007076026458 ...

# %% [markdown]
# What about if we want to set different colors for markers from different groups or categories?
#
# Let's first generate some data that we can use:

# %%
# Generate data

# Define list of groups and their properties
groups_dict = {  # group: x_mean, x_sigma, y_mean, y_sigma
    'A': [10, 1, 100, 10],
    'B': [45, 5, 50, 5],
    'C': [30, 10, 85, 10],
}

from random import choice

# Generate data
groups = []
xs = []
ys = []
for _ in range(1000):
    group = choice(list(groups_dict.keys()))
    groups.append(group)
    xs.append(gauss(groups_dict[group][0], groups_dict[group][1]))
    ys.append(gauss(groups_dict[group][2], groups_dict[group][3]))
data_groups_dict = {
    'group': groups,
    'x': xs,
    'y': ys,
}
df = pd.DataFrame(data_groups_dict)

# %% [markdown]
# Now, we can create a scatter plot where each marker has a color that depends on the group column:

# %%
fig = px.scatter(df, x='x', y='y', color='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="872a48cc-ab9f-437b-af1a-22cd42535a50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("872a48cc-ab9f-437b-af1a-22cd42535a50")) {                    Plotly.newPlot(                        "872a48cc-ab9f-437b-af1a-22cd42535a50",                        [{"hovertemplate":"group=C\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"C","orientation":"v","showlegend":true,"x":[28.68388061749977,27.989724745539625,31.70860334485318,17.577403412542445,41.24464315410347,47.445870466840475,40.1004299320914,37.56125455438657,25.2454566952635,25.801249236419686,19.927530589225697,32.850230379976175,42.639849127110146,-3.889799324183869,37.586532693913384,12.16688288310753,26.692462631324723,31.493115816836607,33.280982517470704,24.26904768435072,44.41008908707579,34.30543229088066,28.18233913878892,44.31449476744514,11.5833739297283,38.41826280011202,42.12501296268021,24.90918027632486,10.067857240518592,16.583841041921858,20.39753622662626,54.94413651656051,18.74936086236719,28.70220680936333,30.08145313914538,39.62776384520474,35.35355322656041,23.870077788600188,32.69542509282396,29.603488530919638,24.93947966640881,23.7901147527909,23.57140726037071,15.949242614375422,22.1795135457222,15.512571231001617,30.769266205266426,27.023396492403876,17.861211552664056,14.352999682643032,22.988137375252514,36.53405812658412,30.02285377107976,28.010557037958353,42.71799892292149,20.60600094162554,29.02385029512264,48.722822462478305,20.545047491872467,16.719528715756393,20.222787733810186,43.15852263299729,41.524978174712444,29.071382251003516,34.6443067791345,19.138995474448436,39.404921717898034,32.36567677877208,45.31715120343523,42.56214851194426,38.1007642383957,35.75435603327789,34.23574297134539,46.265589610172746,25.1232321965574,35.985683450095955,26.983535646322746,24.04411225754626,37.81212158162206,2.3323317017562353,16.953054214757252,48.564135840733904,43.58403589716115,11.245604774898105,18.791105111563873,40.80317392006947,17.11681611867332,37.48635082322752,32.09184346319634,18.22367594564524,23.541587369139037,20.886147820202872,36.20801832662989,26.12333357963197,35.78107422422864,43.39181941710923,12.950154614338764,43.723441967706336,46.29259878853583,27.113528804925004,34.95502071247176,53.20117496620494,41.86162222991365,11.444610975123883,28.78643350455611,16.370827479723914,34.47142831296817,29.33512889568915,24.570974325909432,32.3278042107938,22.58247075100502,42.80847861161443,29.220956719878927,31.71778650888844,23.32657829219999,34.351920066888155,15.327854740575136,25.016414132613995,34.3338513690379,22.099196697052026,28.127083663188234,26.877777836584134,31.005911995682922,21.30711012388507,20.522262047900742,45.25116032272166,27.543731135348043,14.349594117099763,38.84320446152576,28.298441930478205,22.80563300483582,40.76487044004004,35.5639273452104,36.61707084923219,33.56941125693952,26.767420522321814,11.885617331975315,34.45300457021116,26.214791129241256,31.45050082230605,29.019693157282592,34.04692292540942,22.48887290542742,21.96285200182571,26.858518865778617,49.85831013031221,21.470274329440056,40.712505278401956,27.201301308603497,19.27127281592651,32.337012108405375,37.2841935762442,33.24972116319778,27.675753459994823,42.945212674792735,24.658001712903705,34.810847122952765,41.318945077850145,40.67354719759953,34.61357337904717,35.52473663687735,6.868182903415921,16.637654344624696,53.37932463288887,20.80632223968105,13.02134028415955,28.99872663459437,44.8049741772588,32.225739928781294,35.610829744115506,37.38676395285034,23.476572373134776,33.874644201045115,42.303016280914 ...

# %% [markdown]
# We can also choose to use different marker types (i.e. symbols) with the the ```symbol``` argument, as you can see below:

# %%
fig = px.scatter(df, x='x', y='y', color='group', symbol='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b2708d07-e4fc-447e-a9b3-3968c79dcd9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2708d07-e4fc-447e-a9b3-3968c79dcd9a")) {                    Plotly.newPlot(                        "b2708d07-e4fc-447e-a9b3-3968c79dcd9a",                        [{"hovertemplate":"group=C\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"C","orientation":"v","showlegend":true,"x":[28.68388061749977,27.989724745539625,31.70860334485318,17.577403412542445,41.24464315410347,47.445870466840475,40.1004299320914,37.56125455438657,25.2454566952635,25.801249236419686,19.927530589225697,32.850230379976175,42.639849127110146,-3.889799324183869,37.586532693913384,12.16688288310753,26.692462631324723,31.493115816836607,33.280982517470704,24.26904768435072,44.41008908707579,34.30543229088066,28.18233913878892,44.31449476744514,11.5833739297283,38.41826280011202,42.12501296268021,24.90918027632486,10.067857240518592,16.583841041921858,20.39753622662626,54.94413651656051,18.74936086236719,28.70220680936333,30.08145313914538,39.62776384520474,35.35355322656041,23.870077788600188,32.69542509282396,29.603488530919638,24.93947966640881,23.7901147527909,23.57140726037071,15.949242614375422,22.1795135457222,15.512571231001617,30.769266205266426,27.023396492403876,17.861211552664056,14.352999682643032,22.988137375252514,36.53405812658412,30.02285377107976,28.010557037958353,42.71799892292149,20.60600094162554,29.02385029512264,48.722822462478305,20.545047491872467,16.719528715756393,20.222787733810186,43.15852263299729,41.524978174712444,29.071382251003516,34.6443067791345,19.138995474448436,39.404921717898034,32.36567677877208,45.31715120343523,42.56214851194426,38.1007642383957,35.75435603327789,34.23574297134539,46.265589610172746,25.1232321965574,35.985683450095955,26.983535646322746,24.04411225754626,37.81212158162206,2.3323317017562353,16.953054214757252,48.564135840733904,43.58403589716115,11.245604774898105,18.791105111563873,40.80317392006947,17.11681611867332,37.48635082322752,32.09184346319634,18.22367594564524,23.541587369139037,20.886147820202872,36.20801832662989,26.12333357963197,35.78107422422864,43.39181941710923,12.950154614338764,43.723441967706336,46.29259878853583,27.113528804925004,34.95502071247176,53.20117496620494,41.86162222991365,11.444610975123883,28.78643350455611,16.370827479723914,34.47142831296817,29.33512889568915,24.570974325909432,32.3278042107938,22.58247075100502,42.80847861161443,29.220956719878927,31.71778650888844,23.32657829219999,34.351920066888155,15.327854740575136,25.016414132613995,34.3338513690379,22.099196697052026,28.127083663188234,26.877777836584134,31.005911995682922,21.30711012388507,20.522262047900742,45.25116032272166,27.543731135348043,14.349594117099763,38.84320446152576,28.298441930478205,22.80563300483582,40.76487044004004,35.5639273452104,36.61707084923219,33.56941125693952,26.767420522321814,11.885617331975315,34.45300457021116,26.214791129241256,31.45050082230605,29.019693157282592,34.04692292540942,22.48887290542742,21.96285200182571,26.858518865778617,49.85831013031221,21.470274329440056,40.712505278401956,27.201301308603497,19.27127281592651,32.337012108405375,37.2841935762442,33.24972116319778,27.675753459994823,42.945212674792735,24.658001712903705,34.810847122952765,41.318945077850145,40.67354719759953,34.61357337904717,35.52473663687735,6.868182903415921,16.637654344624696,53.37932463288887,20.80632223968105,13.02134028415955,28.99872663459437,44.8049741772588,32.225739928781294,35.610829744115506,37.38676395285034,23.476572373134776,33.874644201045115,42.303016280914 ...

# %% [markdown]
# As shown before, we can also change the size of the markers with the ```update_traces()``` function, as you can see below:

# %%
fig = px.scatter(df, x='x', y='y', color='group', symbol='group')
fig.update_traces(marker={'size': 10})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2be45ef1-3d78-448b-b0c9-8473347ee5a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2be45ef1-3d78-448b-b0c9-8473347ee5a9")) {                    Plotly.newPlot(                        "2be45ef1-3d78-448b-b0c9-8473347ee5a9",                        [{"hovertemplate":"group=C\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"C","orientation":"v","showlegend":true,"x":[28.68388061749977,27.989724745539625,31.70860334485318,17.577403412542445,41.24464315410347,47.445870466840475,40.1004299320914,37.56125455438657,25.2454566952635,25.801249236419686,19.927530589225697,32.850230379976175,42.639849127110146,-3.889799324183869,37.586532693913384,12.16688288310753,26.692462631324723,31.493115816836607,33.280982517470704,24.26904768435072,44.41008908707579,34.30543229088066,28.18233913878892,44.31449476744514,11.5833739297283,38.41826280011202,42.12501296268021,24.90918027632486,10.067857240518592,16.583841041921858,20.39753622662626,54.94413651656051,18.74936086236719,28.70220680936333,30.08145313914538,39.62776384520474,35.35355322656041,23.870077788600188,32.69542509282396,29.603488530919638,24.93947966640881,23.7901147527909,23.57140726037071,15.949242614375422,22.1795135457222,15.512571231001617,30.769266205266426,27.023396492403876,17.861211552664056,14.352999682643032,22.988137375252514,36.53405812658412,30.02285377107976,28.010557037958353,42.71799892292149,20.60600094162554,29.02385029512264,48.722822462478305,20.545047491872467,16.719528715756393,20.222787733810186,43.15852263299729,41.524978174712444,29.071382251003516,34.6443067791345,19.138995474448436,39.404921717898034,32.36567677877208,45.31715120343523,42.56214851194426,38.1007642383957,35.75435603327789,34.23574297134539,46.265589610172746,25.1232321965574,35.985683450095955,26.983535646322746,24.04411225754626,37.81212158162206,2.3323317017562353,16.953054214757252,48.564135840733904,43.58403589716115,11.245604774898105,18.791105111563873,40.80317392006947,17.11681611867332,37.48635082322752,32.09184346319634,18.22367594564524,23.541587369139037,20.886147820202872,36.20801832662989,26.12333357963197,35.78107422422864,43.39181941710923,12.950154614338764,43.723441967706336,46.29259878853583,27.113528804925004,34.95502071247176,53.20117496620494,41.86162222991365,11.444610975123883,28.78643350455611,16.370827479723914,34.47142831296817,29.33512889568915,24.570974325909432,32.3278042107938,22.58247075100502,42.80847861161443,29.220956719878927,31.71778650888844,23.32657829219999,34.351920066888155,15.327854740575136,25.016414132613995,34.3338513690379,22.099196697052026,28.127083663188234,26.877777836584134,31.005911995682922,21.30711012388507,20.522262047900742,45.25116032272166,27.543731135348043,14.349594117099763,38.84320446152576,28.298441930478205,22.80563300483582,40.76487044004004,35.5639273452104,36.61707084923219,33.56941125693952,26.767420522321814,11.885617331975315,34.45300457021116,26.214791129241256,31.45050082230605,29.019693157282592,34.04692292540942,22.48887290542742,21.96285200182571,26.858518865778617,49.85831013031221,21.470274329440056,40.712505278401956,27.201301308603497,19.27127281592651,32.337012108405375,37.2841935762442,33.24972116319778,27.675753459994823,42.945212674792735,24.658001712903705,34.810847122952765,41.318945077850145,40.67354719759953,34.61357337904717,35.52473663687735,6.868182903415921,16.637654344624696,53.37932463288887,20.80632223968105,13.02134028415955,28.99872663459437,44.8049741772588,32.225739928781294,35.610829744115506,37.38676395285034,23.476572373134776,33.874644201045115,42.30 ...

# %% [markdown]
# **Note:** We can also set marker sizes using a column from a DataFrame with the ```size``` argument.
#
# For more information about scatter plots, see [plotly.com/python/line-and-scatter/](https://plotly.com/python/line-and-scatter/).

# %% [markdown]
# ### <div id='plotly_export'>2.E. How to export figures?</div>
#
# Plotly figures can be exported to either static image file formats like PNG, SVG and PDF or to HTML files which can be opened in a web browser to remain interactive.
#
# #### Exporting to static images
#
# Static image generation requires either Kaleido (recommended) or orca (legacy). You can install kaleido package in the following way:
#
# ```
# pip install kaleido
# ```
# or
# ```
# pip3 install kaleido
# ```
#
# Then, you just need to add the following line: ```fig.write_image("NAME.FORMAT")```, where ```NAME``` can be anything you want and ```FORMAT``` can be png, jpeg, webp, svg, pdf or eps.
#
# For more information, see [plotly.com/python/static-image-export/](https://plotly.com/python/static-image-export/).
#
# #### Exporting to HTML files
#
# Plotly allows you to save interactive HTML versions of your figures to your local disk. You can do this by adding the following line: ```fig.write_html("NAME.html")```, where ```NAME``` can be any name you wish to use.
#
# For more information, see [plotly.com/python/interactive-html-export/](https://plotly.com/python/interactive-html-export/).

# %% [markdown]
# ## <div id='seaborn'>3. The seaborn library</div>
#
# *"Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics."*

# %% [markdown]
# Let's first import the seaborn library:

# %%
import seaborn as sns

# %% [markdown]
# If the above didn't work, please run the following on a terminal/console:
#
# ```
# pip install seaborn
# ```
# or
# ```
# pip3 install seaborn
# ```
#
# Since seaborn depends on matplotlib, make sure you have matplotlib installed/imported as well. Check <a href="#matplotlib">here</a> for more details.

# %% [markdown]
# ### <div id='plotly_hists'>3.a. Histograms and bar charts</div>
#
# We can create a histogram figure by either using the ```displot()``` or ```histplot()``` functions. Let's use our list of numbers in the ```numbers``` objects that we used before and create a histogram using the ```distplot()``` function and set the width of the bars / bins with the ```binwidth``` argument. If ```binwidth``` is not set, the bin width is chosen automatically.

# %%
sns.displot(numbers, binwidth=1)

# %% [markdown]
# **Note:**
# - If we want to set the number of bins, we need to set the ```bins``` argument. We can also specify the binning directly with the ```bins``` argument by passing an array.
# - If we have a dictionary or a DataFrame, we also need to set the ```x``` argument to reference the data to be plotted.

# %% [markdown]
# Since we know our numbers in the ```numbers``` list are discrete, we can set the ```discrete``` argument to ```True``` for better visualization (i.e. bars will be centered on discrete values).

# %%
sns.displot(numbers, binwidth=1, discrete=True)

# %% [markdown]
# We can also use categorical data in histograms. For better visibility, we could set the ```shrink``` argument to shrink the bars and better highlight the categorical nature of the data. For example:

# %%
# Generate data
sales = [choice(products) for _ in range(100)]

# PLot
sns.displot(sales, shrink=0.8)

# %% [markdown]
# Suppose we have data about sales from different counties. We actually don't but let's generate some data like that:

# %%
# Generate data
country_options = ['Portugal', 'Spain', 'France']
countries = [choice(country_options) for _ in range(1000)]
sales_stat_by_country = {  # mean, std dev
    'Portugal': [100000, 15000],
    'Spain': [120000, 12000],
    'France': [110000, 5000]
}
distributions_dict = {
    'country': countries,
    'sales': [gauss(sales_stat_by_country[country][0], sales_stat_by_country[country][1]) for country in countries]
}

# %% [markdown]
# Let's now plot the distribution of sales independently of the country. Note that I'm also changing the ticks such that the numbers are smaller and setting the width of the bins.

# %%
ax = sns.displot(distributions_dict, x="sales", binwidth=5000)
ticks = ax.axes[0][0].get_xticks()
xlabels = ['{:,.0f}'.format(x/1000) for x in ticks]
ax.set_xticklabels(xlabels)
ax.set(xlabel='sales [k]')

# %% [markdown]
# Let's now see the distribution of sales by country, we just need to set the ```hue``` argument to ```"country"```. I will also set the ```element``` argument to ```"step"``` to improve readability.

# %%
ax = sns.displot(distributions_dict, x="sales", hue="country", element="step", binwidth=5000)
ticks = ax.axes[0][0].get_xticks()
xlabels = ['{:,.0f}'.format(x/1000) for x in ticks]
ax.set_xticklabels(xlabels)
ax.set(xlabel='sales [k]')

# %% [markdown]
# If we wish, we can also stack them, the total shape will match to the first histogram we produced using this data but we will learn about the contribution from eacy country.

# %%
ax = sns.displot(distributions_dict, x="sales", hue="country", multiple="stack", binwidth=5000)
ticks = ax.axes[0][0].get_xticks()
xlabels = ['{:,.0f}'.format(x/1000) for x in ticks]
ax.set_xticklabels(xlabels)
ax.set(xlabel='sales [k]')

# %% [markdown]
# For more information, see [seaborn.pydata.org/tutorial/distributions.html](https://seaborn.pydata.org/tutorial/distributions.html).

# %% [markdown]
# ### <div id='plotly_line_plots'>3.b. Line plots</div>
#
# Line graphs can be made by either using the ```lineplot()``` function or the ```relplot()``` function by setting its ```kind``` argument to ```line```.

# %%
# Let's get total sales for each year
df = pd.DataFrame(sales_dict)
data = df.groupby('year')['sales'].sum().to_frame()

# Create a line plot
sns.lineplot(data=data, x='year', y='sales')
# Out:
# <Axes: xlabel='year', ylabel='sales'>

# %% [markdown]
# **Note:** The following would also do the trick: ```sns.relplot(data=data, x='year', y='sales', kind='line')```.

# %% [markdown]
# #### Aggregating data
#
# If there are multiple ```y``` values for the same ```x``` value, seaborn will aggregate the data at each ```x``` value by plotting the mean and the 95% confidence interval around the mean. This happens for both ```lineplot()``` and ```relplot()``` functions. Example:

# %%
# Generate data
x_options = np.arange(1, 11)
n_points = 1000
xs = [choice(x_options) for _ in range(n_points)]
ys = [x + gauss(x, 0.3*x) for x in xs]
my_data_dict = {
    'x': xs,
    'y': ys
}

# Plot aggregated data
sns.lineplot(data=my_data_dict, x="x", y="y")
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# #### Comparing multiple line charts
#
# Similarly to Plotly, we can use another variable to split a line into more lines. The only difference is that we must use the ```hue``` argument (instead of ```color``` as in Plotly). Let's re-use our ```sales_dict``` and plot sales for every year for every country:

# %%
sns.lineplot(data=sales_dict, x='year', y='sales', hue='country')
# Out:
# <Axes: xlabel='year', ylabel='sales'>

# %% [markdown]
# Furthermore, we can also change the style of each line by setting the ```style``` argument to the same variable used with the ```hue``` argument:

# %%
sns.lineplot(data=sales_dict, x='year', y='sales', hue='country', style='country')
# Out:
# <Axes: xlabel='year', ylabel='sales'>

# %% [markdown]
# We can also set ```markers``` to ```True``` to show markers:

# %%
sns.lineplot(data=sales_dict, x='year', y='sales', hue='country', style='country', markers=True)
# Out:
# <Axes: xlabel='year', ylabel='sales'>

# %% [markdown]
# **Note:** Here both marker and line styles are different and based on the country. There is no need to specifically say that we want dedicated markers and line styles, setting the ```style``` argument is enough.
#
# For more information about line plots, see [seaborn.pydata.org/tutorial/relational.html](https://seaborn.pydata.org/tutorial/relational.html).

# %% [markdown]
# ### <div id='plotly_scatter_plots'>3.c. Scatter plots</div>
#
# Scatter graphs can be made by either using the ```scatterplot()``` function or the ```relplot()``` function (with ```kind="scatter"``` which is the default).
#
# Let's re-use our ```x_scattered``` and ```y_scattered``` variables and make a scatter figure:

# %%
sns.scatterplot(x=x_scattered, y=y_scattered)
# Out:
# <Axes: >

# %% [markdown]
# As with line plots, we can color data and set the style based on a third variable by using the ```hue``` and ```style``` arguments, respectively. Let's re-use our ```data_groups_dict``` and see how it looks like:

# %%
sns.scatterplot(data_groups_dict, x='x', y='y', hue='group', style='group')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Let's not forget that seaborn is based on matplotlib. All functions that we will see here return something of type ```matplotlib.axes.Axes``` which are the matplotlib axes containing the plot. We can take advantage of that and do further styling. For example, we can change the size of all markers in the following way:

# %%
ax = sns.scatterplot(data_groups_dict, x='x', y='y', hue='group', style='group')
ax.collections[0].set_sizes([60])
ax.redraw_in_frame()

# %% [markdown]
# **Note:** We can also make the size of each marker depend on a given variable by setting the ```size``` argument in ```scatterplot()``` or ```relplot()```.

# %% [markdown]
# For more information about scatter plots, see [seaborn.pydata.org/tutorial/relational.html](https://seaborn.pydata.org/tutorial/relational.html).

# %% [markdown]
# ### <div id='plotly_savefig'>3.d. How to export figures?</div>
#
# Whenever we use a function from seaborn, we need to save what the function returns to a variable (let's call it ```ax```). Then, we just need to add the following line:
#
# ```
# ax.get_figure().savefig("NAME.FORMAT")
# ```
#
# where ```NAME``` can be anything and ```FORMAT``` can be png, jpg, svg or pdf.

# %% [markdown]
# That's all for now. If you wish to learn some tips and other python modules, take a look at the next notebook (#6).
